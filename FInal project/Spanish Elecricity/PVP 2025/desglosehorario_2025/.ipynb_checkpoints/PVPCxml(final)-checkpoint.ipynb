# %%
import os
import pandas as pd
from lxml import etree

# 📂 Carpeta donde están los archivos XML
CARPETA_XML = "/Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025"  # Cambia esto si los archivos están en otra carpeta
ARCHIVO_SALIDA = "datos_xml_limpios.csv"

# 📌 Función para obtener atributos XML de forma segura
def get_attrib(element, attrib):
    return element.get(attrib) if element is not None else None

# 📌 Lista para almacenar los datos de todos los archivos
todos_los_datos = []

# 📂 Recorrer todos los archivos XML en la carpeta
for archivo in os.listdir(CARPETA_XML):
    if archivo.endswith(".xml"):  # Procesar solo archivos XML
        ruta_xml = os.path.join(CARPETA_XML, archivo)
        print(f"📖 Procesando: {ruta_xml}")

        # Cargar el XML
        tree = etree.parse(ruta_xml)
        root = tree.getroot()

        # 📆 Extraer la fecha del nombre del archivo
        fecha_str = archivo[-12:-4]  # Extrae 'yyyymmdd'
        fecha_formateada = pd.to_datetime(fecha_str, format="%Y%m%d").strftime("%m/%d/%Y")

        # Extraer datos de SeriesTemporales
        series_data = []
        for serie in root.findall(".//{*}SeriesTemporales"):
            serie_dict = {
                "Fecha": fecha_formateada,  # Agregar la fecha extraída
                "TerminoCosteHorario": get_attrib(serie.find(".//{*}TerminoCosteHorario"), "v"),
                "TipoPrecio": get_attrib(serie.find(".//{*}TipoPrecio"), "v"),
            }
            
            # Extraer intervalos de tiempo dentro de SeriesTemporales
            for intervalo in serie.findall(".//{*}Intervalo"):
                serie_dict_copy = serie_dict.copy()  # Copia la serie base para cada intervalo
                serie_dict_copy["Hour"] = get_attrib(intervalo.find(".//{*}Pos"), "v")
                serie_dict_copy["Ctd"] = get_attrib(intervalo.find(".//{*}Ctd"), "v")
                series_data.append(serie_dict_copy)

        # Agregar los datos de este archivo a la lista general
        todos_los_datos.extend(series_data)

# 📌 Convertir a DataFrame
df = pd.DataFrame(todos_los_datos)

# 📌 1. Eliminar columnas innecesarias
df = df.drop(columns=["UnidadPrecio"], errors="ignore")  # Asegurar que existe antes de borrar

# 📌 2. Filtrar filas por criterios
df = df[(df["TerminoCosteHorario"] == "FEU") & (df["TipoPrecio"] == "Z14")]

# 📌 3. Reemplazar la columna 'Hour' (antes Pos) y cambiar 24 → 0
df["Hour"] = df["Hour"].replace(24, 0)

# 📌 4. Ordenar por Fecha y Hour
df = df.sort_values(by=["Fecha", "Hour"], ascending=[True, True])

# 📌 5. Guardar el archivo final limpio
df.to_csv(ARCHIVO_SALIDA, index=False, encoding="utf-8")

# 📊 Mostrar las primeras filas del resultado
print(f"✅ Datos procesados y guardados en {ARCHIVO_SALIDA}")
print(df.head())
# Out:
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250203.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250217.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250216.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250202.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250214.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250228.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250201.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250215.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250211.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250205.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250204.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250210.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250206.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250212.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250213.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250207.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250314.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250116.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250102.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250103.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250117.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250301.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250315.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250303.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250317.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250101.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250115.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250129.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250128.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250114.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250316.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250302.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250306.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250312.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250104.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250110.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250111.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250105.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250313.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250307.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250311.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250305.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250113.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250107.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250106.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250112.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250304.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250310.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250321.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250309.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250123.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250122.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250308.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250320.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250322.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250120.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250108.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250109.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250121.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250323.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250119.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250125.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250131.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250130.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250124.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250118.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250326.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250318.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250324.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250126.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250127.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250325.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250319.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250222.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250223.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250221.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250209.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250208.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250220.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250218.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250224.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250225.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250219.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250227.xml
# 📖 Procesando: /Users/Esteban/Documents/Electricity PVP/PVP 2025/desglosehorario_2025/pvpcdesglosehorario_20250226.xml
# ✅ Datos procesados y guardados en datos_xml_limpios.csv
#             Fecha TerminoCosteHorario TipoPrecio Hour             Ctd
# 15840  01/01/2025                 FEU        Z14    1   0.18278526062
# 15849  01/01/2025                 FEU        Z14   10  0.423149353483
# 15850  01/01/2025                 FEU        Z14   11  0.074950803366
# 15851  01/01/2025                 FEU        Z14   12  0.049752809902
# 15852  01/01/2025                 FEU        Z14   13  0.045809314954

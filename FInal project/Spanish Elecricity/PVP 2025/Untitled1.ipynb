# %%
import pandas as pd
import os

# %%
extract_dir = 'Documents/Electricity_PVP/PVP 2025'

# %%
print("Files in directory:", os.listdir(extract_dir))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 print("Files in directory:", os.listdir(extract_dir))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Documents/Electricity PVP/PVP 2025'

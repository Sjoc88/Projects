# %%
import os
import pandas as pd
from lxml import etree

# 📂 Carpeta donde están los archivos XML
CARPETA_XML = "/Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026"  # Cambia esto si los archivos están en otra carpeta
ARCHIVO_SALIDA = "/Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/datos_xml_limpios.csv"

# 📌 Función para obtener atributos XML de forma segura
def get_attrib(element, attrib):
    return element.get(attrib) if element is not None else None

# 📌 Lista para almacenar los datos de todos los archivos
todos_los_datos = []

# 📂 Recorrer todos los archivos XML en la carpeta
for archivo in os.listdir(CARPETA_XML):
    if archivo.endswith(".xml"):  # Procesar solo archivos XML
        ruta_xml = os.path.join(CARPETA_XML, archivo)
        print(f"📖 Procesando: {ruta_xml}")

        # Cargar el XML
        tree = etree.parse(ruta_xml)
        root = tree.getroot()

        # 📆 Extraer la fecha del nombre del archivo
        fecha_str = archivo[-12:-4]  # Extrae 'yyyymmdd'
        fecha_formateada = pd.to_datetime(fecha_str, format="%Y%m%d").strftime("%m/%d/%Y")

        # Extraer datos de SeriesTemporales
        series_data = []
        for serie in root.findall(".//{*}SeriesTemporales"):
            serie_dict = {
                "Fecha": fecha_formateada,  # Agregar la fecha extraída
                "TerminoCosteHorario": get_attrib(serie.find(".//{*}TerminoCosteHorario"), "v"),
                "TipoPrecio": get_attrib(serie.find(".//{*}TipoPrecio"), "v"),
            }
            
            # Extraer intervalos de tiempo dentro de SeriesTemporales
            for intervalo in serie.findall(".//{*}Intervalo"):
                serie_dict_copy = serie_dict.copy()  # Copia la serie base para cada intervalo
                serie_dict_copy["Hour"] = get_attrib(intervalo.find(".//{*}Pos"), "v")
                serie_dict_copy["Ctd"] = get_attrib(intervalo.find(".//{*}Ctd"), "v")
                series_data.append(serie_dict_copy)

        # Agregar los datos de este archivo a la lista general
        todos_los_datos.extend(series_data)

# 📌 Convertir a DataFrame
df = pd.DataFrame(todos_los_datos)

# 📌 1. Eliminar columnas innecesarias
df = df.drop(columns=["UnidadPrecio"], errors="ignore")  # Asegurar que existe antes de borrar

# 📌 2. Filtrar filas por criterios
df = df[(df["TerminoCosteHorario"] == "FEU")]

# 📌 3. Reemplazar la columna 'Hour' (antes Pos) y cambiar 24 → 0
df["Hour"] = df["Hour"].replace(24, 0)

# 📌 4. Ordenar por Fecha y Hour
df = df.sort_values(by=["Fecha", "Hour"], ascending=[True, True])

# 📌 5. Guardar el archivo final limpio
df.to_csv(ARCHIVO_SALIDA, index=False, encoding="utf-8")

# 📊 Mostrar las primeras filas del resultado
print(f"✅ Datos procesados y guardados en {ARCHIVO_SALIDA}")
print(df.head())
# Out:
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260101.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260115.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260129.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260128.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260114.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260116.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260102.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260103.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260117.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260113.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260107.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260106.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260112.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260104.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260110.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260111.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260105.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260120.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260108.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260109.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260121.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260123.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260122.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260126.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260127.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260119.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260125.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260131.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260130.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260124.xml
# 📖 Procesando: /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/desglosehorario_2026/pvpcdesglosehorario_20260118.xml
# ✅ Datos procesados y guardados en /Users/stephane.orts/Documents/GitHub/Projects/FInal project/Spanish Elecricity/PVP 2026/datos_xml_limpios_2026.csv
#           Fecha TerminoCosteHorario TipoPrecio Hour             Ctd
# 216  01/01/2026                 FEU        Z24    1  0.148103455714
# 240  01/01/2026                 FEU        Z14    1  0.148103455714
# 225  01/01/2026                 FEU        Z24   10  0.126637999475
# 249  01/01/2026                 FEU        Z14   10  0.126637999475
# 226  01/01/2026                 FEU        Z24   11  0.105739359728
